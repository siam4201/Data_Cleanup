# 34    35     S Chanderpaul (WI)  1994-2015  164   280  49  11867  203*  51.37
# 35    36      SM Gavaskar (IND)  1971-1987  125   214  16  10122  236*  51.12
# 36    37         SR Waugh (AUS)  1985-2004  168   260  46  10927   200  51.06
# 37    38          JE Root (ENG)  2012-2025  159   290  24  13551   262  50.94
# 38    39        ML Hayden (AUS)  1994-2009  103   184  14   8625   380  50.73
# 39    40    AB de Villiers (SA)  2004-2018  114   191  18   8765  278*  50.66
# 40    41        AR Border (AUS)  1978-1994  156   265  44  11174   205  50.56
# 41    42      IVA Richards (WI)  1974-1991  121   182  12   8540   291  50.23
# 42    43      DCS Compton (ENG)  1937-1957   78   131  15   5807   278  50.06
#
#         BF     SR  100  50     0     4s   6s
# 0    9800+  58.60   29  13   7.0   626+    6
# 1     2063  63.79    5   5   NaN    137   24
# 2     2667  55.68    5   4   2.0    186    5
# 3    1707+  54.48    7  11   1.0   246+   11
# 4     416+  56.00   10   5   2.0   104+    1
# 5    6558+  34.59   16  23   2.0   202+    6
# 6    1288+  45.88    4   7   3.0   125+    4
# 7    4957+  42.42   20  35   5.0   591+   27
# 8      NaN    NaN   15  19   6.0   258+    2
# 9    7491+  38.07   22  24   4.0   419+   27
# 10   4063+  53.58   26  30  12.0   593+  32+
# 11   22882  54.19   38  52  11.0   1491   51
# 12   5363+  46.22   15  28   4.0   276+    8
# 13     NaN    NaN   15  14   1.0   107+   11
# 14   2844+  39.34   19  33   5.0   358+    7
# 15    3286  87.40   10  14   4.0    313   48
# 16   19570  53.63   36  43  11.0   1145   62
# 17   28903  45.97   45  58  16.0   1488   97
# 18    178+  29.21    3   6   2.0    37+    2
# 19   17913  51.78   33  37  11.0   1031   27
# 20    665+  35.48    4   4   1.0    65+    1
# 21    1823  59.46    4   3   3.0    124    6
# 22  13079+  51.53   24  31  12.0    755   16
# 23    108+  63.88    9  14   3.0   115+    6
# 24  29437+  54.04   51  68  14.0  2058+   69
# 25   19753  60.51   34  48  17.0   1559   88
# 26  15164+  45.99   23  43   6.0   788+   48
# 27   31258  42.51   36  63   8.0   1654   21
# 28   14372  52.39   24  33  11.0    957   51
# 29   19375  52.12   34  33  19.0   1082   70
# 30   22782  58.72   41  62  17.0   1509   73
# 31   2035+  44.86    3   9   1.0   102+    3
# 32   10636  45.07   12  27   5.0    543   20
# 33   12436  50.13   19  29  12.0    685   39
# 34   27395  43.31   30  66  15.0   1285   36
# 35  14184+  43.35   34  45  12.0   908+   26
# 36   22461  48.64   32  50  22.0   1175   20
# 37   23574  57.48   39  66  14.0   1452   45
# 38   14349  60.10   30  29  14.0   1049   82
# 39   16077  54.51   22  46   8.0   1024   64
# 40  27002+  41.09   27  63  11.0   1161   28
# 41   9613+  69.77   24  45  10.0   952+   84
# 42   2731+  38.81   17  28  10.0   342+    3

# %%
df = df.rename(columns = {
                    
                    'Span':'span',
                    'Mat':'matches_played',
                    'Inns':'innings',
                    'NO':'not_out',
                    'Runs':'runs',
                    'HS':'highest_inns_score',
                    'Ave':'batting_average',
                    'BF':'balls_faced',
                    'SR':'strike_rate',
                    '100':'hundreds_scored',
                    '50':'fifties_scored',
                    '0':'ducks_scored',
                    '4s':'fours',
                    '6s':'sixes',
                    'Player':'player',
                    'Rank':'rank'

})

# %% [markdown]
# Check null and empty

# %%
df.isna().sum()
# Out:
# rank                  0
# player                0
# span                  0
# matches_played        0
# innings               0
# not_out               0
# runs                  0
# highest_inns_score    0
# batting_average       0
# balls_faced           2
# strike_rate           2
# hundreds_scored       0
# fifties_scored        0
# ducks_scored          1
# fours                 0
# sixes                 0
# dtype: int64

# %%
df.isnull().any()
# Out:
# rank                  False
# player                False
# span                  False
# matches_played        False
# innings               False
# not_out               False
# runs                  False
# highest_inns_score    False
# batting_average       False
# balls_faced            True
# strike_rate            True
# hundreds_scored       False
# fifties_scored        False
# ducks_scored           True
# fours                 False
# sixes                 False
# dtype: bool

# %% [markdown]
# Clean balls_faced and convert to int

# %%
df[df['balls_faced'].isna() == 1]
# Out:
#     rank           player       span  matches_played  innings  not_out  runs  \
# 8      9   ED Weekes (WI)  1948-1958              48       81        5  4455
# 13    14  CL Walcott (WI)  1948-1960              44       74        7  3798
#
#    highest_inns_score  batting_average balls_faced  strike_rate  \
# 8                 207            58.61         NaN          NaN
# 13                220            56.68         NaN          NaN
#
#     hundreds_scored  fifties_scored  ducks_scored fours sixes
# 8                15              19           6.0  258+     2
# 13               15              14           1.0  107+    11

# %%
df['balls_faced']=df['balls_faced'].str.split('+').str.get(0)

# %%
df['balls_faced'] = pd.to_numeric(df['balls_faced'], errors='coerce')

# %% [markdown]
# Check if there are outliers

# %%
q1 = df['balls_faced'].quantile(0.25)
q3 = df['balls_faced'].quantile(0.75)
IQR = q3 - q1

lower_fence = q1 - 1.5 * IQR
upper_fence = q3 + 1.5 * IQR

outliers = df[(df['balls_faced'] < lower_fence) | (df['balls_faced'] > upper_fence)]

print(df['balls_faced'].min())
print(lower_fence)
print(df['balls_faced'].max())
print(upper_fence)

outliers.empty
# Out:
# 108.0
# -22527.5
# 31258.0
# 44828.5
# True

# %% [markdown]
# Fill balls_faced empty values with the mean since there are no outliers of all values

# %%
df['balls_faced'].dtype
# Out:
# dtype('float64')

# %%
df['balls_faced'] = df['balls_faced'].fillna(df['balls_faced'].mean())

# %%
df['balls_faced'] = df['balls_faced'].astype(int)
df
# Out:
#     rank                 player       span  matches_played  innings  not_out  \
# 0      1       DG Bradman (AUS)  1928-1948              52       80       10
# 1      2       PHKD Mendis (SL)  2022-2025              14       24        3
# 2      3         AC Voges (AUS)  2015-2016              20       31        7
# 3      4        RG Pollock (SA)  1963-1970              23       41        4
# 4      5        GA Headley (WI)  1930-1954              22       40        4
# 5      6      H Sutcliffe (ENG)  1924-1935              54       84        9
# 6      7        E Paynter (ENG)  1931-1939              20       31        5
# 19   9276                251            54.88        17913        51.78
# 20   1301                183            54.20          665        35.48
# 21   1084                227            54.20         1823        59.46
# 22   7110               247*            53.86        13079        51.53
# 23   2960                231            53.81          108        63.88
# 24  15921               248*            53.78        29437        54.04
# 25  11953               400*            52.88        19753        60.51
# 26   8832               280*            52.57        15164        45.99
# 27  13288                270            52.31        31258        42.51
# 28   7530                223            52.29        14372        52.39
# 29  10099                313            52.05        19375        52.12
# 30  13378                257            51.85        22782        58.72
# 31   1394               201*            51.62         2035        44.86
# 32   4794               232*            51.54        10636        45.07
# 33   6235                195            51.52        12436        50.13
# 34  11867               203*            51.37        27395        43.31
# 35  10122               236*            51.12        14184        43.35
# 36  10927                200            51.06        22461        48.64
# 37  13551                262            50.94        23574        57.48
# 38   8625                380            50.73        14349        60.10
# 39   8765               278*            50.66        16077        54.51
# 40  11174                205            50.56        27002        41.09
# 41   8540                291            50.23         9613        69.77
# 42   5807                278            50.06         2731        38.81
#
#     hundreds_scored  fifties_scored  ducks_scored  fours sixes
# 0                29              13           7.0   626+     6
# 1                 5               5           NaN    137    24
# 2                 5               4           2.0    186     5
# 3                 7              11           1.0   246+    11
# 4                10               5           2.0   104+     1
# 5                16              23           2.0   202+     6
# 6                 4               7           3.0   125+     4
# 7                20              35           5.0   591+    27
# 8                15              19           6.0   258+     2
# 9                22              24           4.0   419+    27
# 10               26              30          12.0   593+   32+
# 11               38              52          11.0   1491    51
# 12               15              28           4.0   276+     8
# 13               15              14           1.0   107+    11
# 14               19              33           5.0   358+     7
# 15               10              14           4.0    313    48
# 16               36              43          11.0   1145    62
# 17               45              58          16.0   1488    97
# 18                3               6           2.0    37+     2
# 19               33              37          11.0   1031    27
# 20                4               4           1.0    65+     1
# 21                4               3           3.0    124     6
# 22               24              31          12.0    755    16
# 23                9              14           3.0   115+     6
# 24               51              68          14.0  2058+    69
# 25               34              48          17.0   1559    88
# 26               23              43           6.0   788+    48
# 27               36              63           8.0   1654    21
# 28               24              33          11.0    957    51
# 29               34              33          19.0   1082    70
# 30               41              62          17.0   1509    73
# 31                3               9           1.0   102+     3
# 32               12              27           5.0    543    20
# 33               19              29          12.0    685    39
# 34               30              66          15.0   1285    36
# 35               34              45          12.0   908+    26
# 36               32              50          22.0   1175    20
# 37               39              66          14.0   1452    45
# 38               30              29          14.0   1049    82
# 39               22              46           8.0   1024    64
# 40               27              63          11.0   1161    28
# 41               24              45          10.0   952+    84
# 42               17              28          10.0   342+     3

# %% [markdown]
# Do the same for strike_rate and ducks_scored

# %%
df[(df['strike_rate'].isna() == 1) | (df['ducks_scored'].isna() == 1)]
# Out:
#     rank            player       span  matches_played  innings  not_out  runs  \
# 1      2  PHKD Mendis (SL)  2022-2025              14       24        3  1316
# 8      9    ED Weekes (WI)  1948-1958              48       81        5  4455
# 13    14   CL Walcott (WI)  1948-1960              44       74        7  3798
#
#    highest_inns_score  batting_average  balls_faced  strike_rate  \
# 1                182*            62.66         2063        63.79
# 8                 207            58.61        12006          NaN
# 13                220            56.68        12006          NaN
#
#     hundreds_scored  fifties_scored  ducks_scored fours sixes
# 1                 5               5           NaN   137    24
# 8                15              19           6.0  258+     2
# 13               15              14           1.0  107+    11

# %%
df.dtypes
# Out:
# rank                    int64
# player                 object
# span                   object
# matches_played          int64
# innings                 int64
# not_out                 int64
# runs                    int64
# highest_inns_score     object
# batting_average       float64
# balls_faced             int64
# strike_rate           float64
# hundreds_scored         int64
# fifties_scored          int64
# ducks_scored          float64
# fours                  object
# sixes                  object
# dtype: object

# %%
IQSR1 = df['strike_rate'].quantile(0.25)
IQSR3 = df['strike_rate'].quantile(0.75)
IQSRR = IQSR3 - IQSR1

IQDS1 = df['ducks_scored'].quantile(0.25)
IQDS3 = df['ducks_scored'].quantile(0.75)
IQDSR = IQDS3 - IQDS1

lower_fenceSR = IQSR1 - (1.5 * IQSRR)
upper_fenceSR = IQSR3 + (1.5 * IQSRR)
outlierSR = df[(df['strike_rate']<lower_fenceSR) | (df['strike_rate']>upper_fenceSR)]

lower_fenceDS = IQDS1 - (1.5 * IQDSR)
upper_fenceDS = IQDS3 + (1.5 * IQDSR)
outlierDS = df[(df['ducks_scored']<lower_fenceDS) | (df['ducks_scored']>upper_fenceDS)]

print(outlierSR.empty)
print(outlierDS.empty)


print(df['strike_rate'].min())
print(lower_fenceSR)
print(df['strike_rate'].max())
print(upper_fenceSR)
# Out:
# False
# True
# 29.21
# 24.375000000000004
# 87.4
# 74.975

# %% [markdown]
# Dataset has outliers in strike_rate column but not in ducks_scored. so we'll use median for strike_rate and mean for ducks_scored.

# %%
df['strike_rate'] = df['strike_rate'].fillna(df['strike_rate'].median())
df['ducks_scored'] = df['ducks_scored'].fillna(df['ducks_scored'].mean())

# %%
df[(df['strike_rate'].isna() == 1) | (df['ducks_scored'].isna() == 1)]
# Out:
# Empty DataFrame
# Columns: [rank, player, span, matches_played, innings, not_out, runs, highest_inns_score, batting_average, balls_faced, strike_rate, hundreds_scored, fifties_scored, ducks_scored, fours, sixes]
# Index: []

# %% [markdown]
# Check for duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# dtype: bool

# %% [markdown]
# Split span to start and end and drop span afterward

# %%
df['rookie_year'] = df['span'].str.split(pat = '-').str.get(0)
df['final_year'] = df['span'].str.split(pat = '-').str.get(1)
df = df.drop(['span'], axis = 1)

# %%
df
# Out:
#     rank                 player  matches_played  innings  not_out   runs  \
# 0      1       DG Bradman (AUS)              52       80       10   6996
# 1      2       PHKD Mendis (SL)              14       24        3   1316
# 2      3         AC Voges (AUS)              20       31        7   1485
# 3      4        RG Pollock (SA)              23       41        4   2256
# 4      5        GA Headley (WI)              22       40        4   2190
# 5      6      H Sutcliffe (ENG)              54       84        9   4555
# 6      7        E Paynter (ENG)              20       31        5   1540
# 7      8    KF Barrington (ENG)              82      131       15   6806
# 8      9         ED Weekes (WI)              48       81        5   4455
# 9     10       WR Hammond (ENG)              85      140       16   7249
# 10    11         GS Sobers (WI)              93      160       21   8032
# 11    12     KC Sangakkara (SL)             134      233       17  12400
# 12    13         JB Hobbs (ENG)              61      102        7   5410
# 13    14        CL Walcott (WI)              44       74        7   3798
# 14    15         L Hutton (ENG)              79      138       15   6971
# 15    16         HC Brook (ENG)              31       52        1   2872
# 16    17        SPD Smith (AUS)             120      214       26  10496
# 17    18     JH Kallis (ICC/SA)             166      280       40  13289
# 18    19     GE Tyldesley (ENG)              14       20        2    990
# 19    20     KS Williamson (NZ)             105      186       17   9276
# 20    21          CA Davis (WI)              15       29        5   1301
# 21    22        VG Kambli (IND)              17       21        1   1084
# 22    23      GS Chappell (AUS)              87      151       19   7110
# 23    24         AD Nourse (SA)              34       62        7   2960
# 24    25     SR Tendulkar (IND)             200      329       33  15921
# 25    26       BC Lara (ICC/WI)             131      232        6  11953
# 26    27    Javed Miandad (PAK)             124      189       21   8832
# 27    28     R Dravid (ICC/IND)             164      286       32  13288
# 28    29  Mohammad Yousuf (PAK)              90      156       12   7530
# 29    30      Younis Khan (PAK)             118      213       19  10099
# 30    31       RT Ponting (AUS)             168      287       29  13378
# 31    32          J Ryder (AUS)              20       32        5   1394
# 32    33         A Flower (ZIM)              63      112       19   4794
# 33    34       MEK Hussey (AUS)              79      137       16   6235
# 34    35     S Chanderpaul (WI)             164      280       49  11867
# 35    36      SM Gavaskar (IND)             125      214       16  10122
# 36    37         SR Waugh (AUS)             168      260       46  10927
# 37    38          JE Root (ENG)             159      290       24  13551
# 38    39        ML Hayden (AUS)             103      184       14   8625
# 39    40    AB de Villiers (SA)             114      191       18   8765
# 40    41        AR Border (AUS)             156      265       44  11174
# 41    42      IVA Richards (WI)             121      182       12   8540
# 42    43      DCS Compton (ENG)              78      131       15   5807
#
#    highest_inns_score  batting_average  balls_faced  strike_rate  \
# 0                 334            99.94         9800        58.60
# 1                182*            62.66         2063        63.79
# 2                269*            61.87         2667        55.68
# 3                 274            60.97         1707        54.48
# 4                270*            60.83          416        56.00
# 5                 194            60.73         6558        34.59
# 6                 243            59.23         1288        45.88
# 7                 256            58.67         4957        42.42
# 8                 207            58.61        12006        51.78
# 9                336*            58.45         7491        38.07
# 10               365*            57.78         4063        53.58
# 11                319            57.40        22882        54.19
# 12                211            56.94         5363        46.22
# 13                220            56.68        12006        51.78
# 14                364            56.67         2844        39.34
# 15                317            56.31         3286        87.40
# 16                239            55.82        19570        53.63
# 17                224            55.37        28903        45.97
# 18                122            55.00          178        29.21
# 19                251            54.88        17913        51.78
# 20                183            54.20          665        35.48
# 21                227            54.20         1823        59.46
# 22               247*            53.86        13079        51.53
# 23                231            53.81          108        63.88
# 24               248*            53.78        29437        54.04
# 25               400*            52.88        19753        60.51
# 26               280*            52.57        15164        45.99
# 27                270            52.31        31258        42.51
# 28                223            52.29        14372        52.39
# 29                313            52.05        19375        52.12
# 30                257            51.85        22782        58.72
# 31               201*            51.62         2035        44.86
# 32               232*            51.54        10636        45.07
# 33                195            51.52        12436        50.13
# 34               203*            51.37        27395        43.31
# 35               236*            51.12        14184        43.35
# 36                200            51.06        22461        48.64
# 37                262            50.94        23574        57.48
# 38                380            50.73        14349        60.10
# 39               278*            50.66        16077        54.51
# 40                205            50.56        27002        41.09
# 41                291            50.23         9613        69.77
# 42                278            50.06         2731        38.81
#
#     hundreds_scored  fifties_scored  ducks_scored  fours sixes rookie_year  \
# 0                29              13      7.000000   626+     6        1928
# 1                 5               5      8.428571    137    24        2022
# 2                 5               4      2.000000    186     5        2015
# 3                 7              11      1.000000   246+    11        1963
# 4                10               5      2.000000   104+     1        1930
# 5                16              23      2.000000   202+     6        1924
# 6                 4               7      3.000000   125+     4        1931
# 7                20              35      5.000000   591+    27        1955
# 8                15              19      6.000000   258+     2        1948
# 9                22              24      4.000000   419+    27        1927
# 10               26              30     12.000000   593+   32+        1954
# 11               38              52     11.000000   1491    51        2000
# 12               15              28      4.000000   276+     8        1908
# 13               15              14      1.000000   107+    11        1948
# 14               19              33      5.000000   358+     7        1937
# 15               10              14      4.000000    313    48        2022
# 16               36              43     11.000000   1145    62        2010
# 17               45              58     16.000000   1488    97        1995
# 18                3               6      2.000000    37+     2        1921
# 19               33              37     11.000000   1031    27        2010
# 20                4               4      1.000000    65+     1        1968
# 21                4               3      3.000000    124     6        1993
# 22               24              31     12.000000    755    16        1970
# 23                9              14      3.000000   115+     6        1935
# 24               51              68     14.000000  2058+    69        1989
# 25               34              48     17.000000   1559    88        1990
# 26               23              43      6.000000   788+    48        1976
# 27               36              63      8.000000   1654    21        1996
# 28               24              33     11.000000    957    51        1998
# 29               34              33     19.000000   1082    70        2000
# 30               41              62     17.000000   1509    73        1995
# 31                3               9      1.000000   102+     3        1920
# 32               12              27      5.000000    543    20        1992
# 33               19              29     12.000000    685    39        2005
# 34               30              66     15.000000   1285    36        1994
# 35               34              45     12.000000   908+    26        1971
# 36               32              50     22.000000   1175    20        1985
# 37               39              66     14.000000   1452    45        2012
# 38               30              29     14.000000   1049    82        1994
# 39               22              46      8.000000   1024    64        2004
# 40               27              63     11.000000   1161    28        1978
# 41               24              45     10.000000   952+    84        1974
# 42               17              28     10.000000   342+     3        1937
#
#    final_year
# 0        1948
# 1        2025
# 2        2016
# 3        1970
# 4        1954
# 5        1935
# 6        1939
# 7        1968
# 8        1958
# 9        1947
# 10       1974
# 11       2015
# 12       1930
# 13       1960
# 14       1955
# 15       2025
# 16       2025
# 17       2013
# 18       1929
# 19       2024
# 20       1973
# 21       1995
# 22       1984
# 23       1951
# 24       2013
# 25       2006
# 26       1993
# 27       2012
# 28       2010
# 29       2017
# 30       2012
# 31       1929
# 32       2002
# 33       2013
# 34       2015
# 35       1987
# 36       2004
# 37       2025
# 38       2009
# 39       2018
# 40       1994
# 41       1991
# 42       1957

# %% [markdown]
# Split Country from player name

# %%
df['country'] = df['player'].str.split('(').str.get(1)
df['country'].str.split(')').str.get(0)
df['country'] = df['country'].str.split(')').str.get(0)

df['player'] = df['player'].str.split('(').str.get(0)

# %%
df.dtypes
# Out:
# rank                    int64
# player                 object
# matches_played          int64
# innings                 int64
# not_out                 int64
# runs                    int64
# highest_inns_score     object
# batting_average       float64
# balls_faced             int64
# strike_rate           float64
# hundreds_scored         int64
# fifties_scored          int64
# ducks_scored          float64
# fours                  object
# sixes                  object
# rookie_year            object
# final_year             object
# country                object
# dtype: object

# %% [markdown]
# Correct data types

# %%
df['highest_inns_score'] = df['highest_inns_score'].str.split(pat = '*').str.get(0)

# %%
df['highest_inns_score'] = pd.to_numeric(df['highest_inns_score'], errors='coerce')

# %%
df['highest_inns_score'].dtypes
# Out:
# dtype('int64')

# %%
cols = ['rookie_year', 'final_year']
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

# %%
cols = ['player', 'country']
df[cols] = df[cols].astype('string')

# %%
df['fours']=df['fours'].str.split('+').str.get(0)
df['sixes']=df['sixes'].str.split('+').str.get(0)

# %%
cols = ['fours' , 'sixes']
df[cols] = df[cols].apply(pd.to_numeric, errors = 'coerce')

# %%
df['ducks_scored'] = df['ducks_scored'].astype(int)

# %%
df = df.drop(['rank'], axis = 1)

# %% [markdown]
# Save the processed CSV

# %%
##change the output directory accordingly
df.to_csv("D:/ML Projects/Data_Cleanup/data/processed/Processed.csv", index=False)

# %%
df
# Out:
#               player  matches_played  innings  not_out   runs  \
# 0        DG Bradman               52       80       10   6996
# 1       PHKD Mendis               14       24        3   1316
# 2          AC Voges               20       31        7   1485
# 3        RG Pollock               23       41        4   2256
# 4        GA Headley               22       40        4   2190
# 5       H Sutcliffe               54       84        9   4555
# 6         E Paynter               20       31        5   1540
# 7     KF Barrington               82      131       15   6806
# 8         ED Weekes               48       81        5   4455
# 9        WR Hammond               85      140       16   7249
# 10        GS Sobers               93      160       21   8032
# 11    KC Sangakkara              134      233       17  12400
# 12         JB Hobbs               61      102        7   5410
# 13       CL Walcott               44       74        7   3798
# 14         L Hutton               79      138       15   6971
# 15         HC Brook               31       52        1   2872
# 16        SPD Smith              120      214       26  10496
# 17        JH Kallis              166      280       40  13289
# 18     GE Tyldesley               14       20        2    990
# 19    KS Williamson              105      186       17   9276
# 20         CA Davis               15       29        5   1301
# 21        VG Kambli               17       21        1   1084
# 22      GS Chappell               87      151       19   7110
# 23        AD Nourse               34       62        7   2960
# 24     SR Tendulkar              200      329       33  15921
# 25          BC Lara              131      232        6  11953
# 26    Javed Miandad              124      189       21   8832
# 27         R Dravid              164      286       32  13288
# 28  Mohammad Yousuf               90      156       12   7530
# 29      Younis Khan              118      213       19  10099
# 30       RT Ponting              168      287       29  13378
# 31          J Ryder               20       32        5   1394
# 32         A Flower               63      112       19   4794
# 33       MEK Hussey               79      137       16   6235
# 34    S Chanderpaul              164      280       49  11867
# 35      SM Gavaskar              125      214       16  10122
# 36         SR Waugh              168      260       46  10927
# 31                3               9             1    102      3         1920
# 32               12              27             5    543     20         1992
# 33               19              29            12    685     39         2005
# 34               30              66            15   1285     36         1994
# 35               34              45            12    908     26         1971
# 36               32              50            22   1175     20         1985
# 37               39              66            14   1452     45         2012
# 38               30              29            14   1049     82         1994
# 39               22              46             8   1024     64         2004
# 40               27              63            11   1161     28         1978
# 41               24              45            10    952     84         1974
# 42               17              28            10    342      3         1937
#
#     final_year  country
# 0         1948      AUS
# 1         2025       SL
# 2         2016      AUS
# 3         1970       SA
# 4         1954       WI
# 5         1935      ENG
# 6         1939      ENG
# 7         1968      ENG
# 8         1958       WI
# 9         1947      ENG
# 10        1974       WI
# 11        2015       SL
# 12        1930      ENG
# 13        1960       WI
# 14        1955      ENG
# 15        2025      ENG
# 16        2025      AUS
# 17        2013   ICC/SA
# 18        1929      ENG
# 19        2024       NZ
# 20        1973       WI
# 21        1995      IND
# 22        1984      AUS
# 23        1951       SA
# 24        2013      IND
# 25        2006   ICC/WI
# 26        1993      PAK
# 27        2012  ICC/IND
# 28        2010      PAK
# 29        2017      PAK
# 30        2012      AUS
# 31        1929      AUS
# 32        2002      ZIM
# 33        2013      AUS
# 34        2015       WI
# 35        1987      IND
# 36        2004      AUS
# 37        2025      ENG
# 38        2009      AUS
# 39        2018       SA
# 40        1994      AUS
# 41        1991       WI
# 42        1957      ENG

# %% [markdown]
# Visualization

# %% [markdown]
# Player grouping by country

# %%
import plotly.express as px

fig = px.treemap(
    df, 
    path=['country', 'player'], 
    values='runs',               
    color='runs',                              
    color_continuous_scale='RdBu',
    title="Player grouping by country sorted by runs"
)
fig.show()
fig.write_image("D:/ML Projects/Data_Cleanup/plots/1.png")

# %% [markdown]
# Gantt Chart of player career timeline

# %%
df['start_date'] = pd.to_datetime(df['rookie_year'].astype(str) + '-01-01')
df['end_date'] = pd.to_datetime(df['final_year'].astype(str) + '-12-31')


fig = px.timeline(
    df, 
    x_start="start_date", 
    x_end="end_date", 
    y="player", 
    color="matches_played",
    title="Player Career Timelines"
)


fig.update_yaxes(categoryorder="total ascending") 

fig.show()
fig.write_image("D:/ML Projects/Data_Cleanup/plots/2.png")

# %% [markdown]
# Bar chart of how many runs were from running, 4s and 6s

# %%
import plotly.express as px


df['runs_from_4s'] = df['fours'] * 4
df['runs_from_6s'] = df['sixes'] * 6
df['runs_running'] = df['runs'] - (df['runs_from_4s'] + df['runs_from_6s'])


df_boundary = df.melt(
    id_vars=['player'], 
    value_vars=['runs_running', 'runs_from_4s', 'runs_from_6s'],
    var_name='Run Type', 
    value_name='Run Amount'
)


fig = px.bar(
    df_boundary, 
    x="player", 
    y="Run Amount", 
    color="Run Type", 
    title="Run Composition: Running vs. Boundaries",
    
    color_discrete_map={
        'runs_running': "#19191F", 
        'runs_from_4s': '#636EFA', 
        'runs_from_6s': '#EF553B'
    }
)

fig.show()
fig.write_image("D:/ML Projects/Data_Cleanup/plots/3.png")
